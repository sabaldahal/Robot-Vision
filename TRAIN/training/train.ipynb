# %%
import os
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.15 MOdified Local Repo 🚀 Python-3.10.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4070, 11980MiB)
# Setup complete ✅ (32 CPUs, 31.0 GB RAM, 381.5/937.3 GB disk)

# %%
from ultralytics import YOLO

# %%
HOME = os.getcwd()
# !mkdir -p local/datasets/v2
# %cd local/datasets/v2

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="sJNHOIh50A762Dg5rp5e")
project = rf.workspace("robotics25").project("keypoints_design_2-jyrdy")
version = project.version(2)
dataset = version.download("yolov8")

# %%
# %cd {HOME}
# %pwd

# %%
dataset.location

# %%
datasetpath = "/home/sabal/code/spacecraft blender/latest/robot vision/Robot-Vision/local/datasets/version_4 dataset/merged dataset v4"

# %%
print(ultralytics.__version__)
# Out:
# 8.4.15 MOdified Local Repo

# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.4.15
# Summary: Ultralytics YOLO 🚀 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://ultralytics.com
# Author:
# Author-email: Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>
# License: AGPL-3.0
# Location: /home/sabal/code/spacecraft blender/latest/robot vision/Robot-Vision/.venv/lib/python3.10/site-packages
# Editable project location: /home/sabal/code/spacecraft blender/latest/robot vision/Robot-Vision/Modified YOLO/ultralytics
# Requires: matplotlib, numpy, opencv-python, pillow, polars, psutil, pyyaml, requests, scipy, torch, torchvision, ultralytics-thop
# Required-by:

# %% [markdown]
# Check the pose Value in default.yaml file or specify it explicitly here.
# set pose value to 5 if using L1 Loss + OKS (default value might have been changed, best to provide it as an argument)
# set pose value to 12 if using OKS

# %%
model = YOLO("yolo11s-pose.pt")
model.train(data=f"{datasetpath}/data.yaml", epochs=100, imgsz=640, fliplr=0.0, flipud=0.0)
# Out:
# New https://pypi.org/project/ultralytics/8.4.33 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.15 MOdified Local Repo 🚀 Python-3.10.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4070, 11980MiB)
# ...
