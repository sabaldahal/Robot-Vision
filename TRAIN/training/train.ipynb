# %%
import os
import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

# %%
HOME = os.getcwd()
# !mkdir -p local/datasets/v2
# %cd local/datasets/v2

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="sJNHOIh50A762Dg5rp5e")
project = rf.workspace("robotics25").project("keypoints_design_2-jyrdy")
version = project.version(2)
dataset = version.download("yolov8")

# %%
# %cd {HOME}
# %pwd

# %%
dataset.location

# %%
datasetpath = "/Users/sabaldahal/Desktop/College/WORK-RESEARCH LAB/spacecraft blender/src/v2/Robot-Vision/local/working model/update_dec_4_2025/latest renders/final_processed/640"

# %%
import ultralytics
print(ultralytics.__version__)

# %%
model = YOLO("yolov8s-pose.pt")
model.train(data=f"{datasetpath}/data.yaml", epochs=100, imgsz=640)
