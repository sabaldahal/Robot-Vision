# %%
import os
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.189 🚀 Python-3.10.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4070, 11980MiB)
# Setup complete ✅ (32 CPUs, 31.0 GB RAM, 354.5/937.3 GB disk)

# %%
from ultralytics import YOLO

# %%
# %pwd
# Out:
# '/home/sabal/code/spacecraft blender/latest/robot vision/Robot-Vision/TRAIN/training'

# %%
HOME = os.getcwd()

# %%
print(HOME)
# Out:
# /home/sabal/code/spacecraft blender/latest/robot vision/Robot-Vision/TRAIN/training

# %%
# !mkdir -p local/datasets/v2_medium

# %%
# %cd local/datasets/v2_medium
# Out:
# /home/sabal/code/spacecraft blender/latest/robot vision/Robot-Vision/TRAIN/training/local/datasets/v2_medium
# /home/sabal/code/spacecraft blender/latest/robot vision/Robot-Vision/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="sJNHOIh50A762Dg5rp5e")
project = rf.workspace("robotics25").project("keypoints_design_2-jyrdy")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd {HOME}
# %pwd

# %%
dataset.location
# Out:
# '/home/sabal/code/spacecraft blender/latest/robot vision/Robot-Vision/TRAIN/training/local/datasets/v2_medium/keypoints_design_2-2'

# %%
model = YOLO("yolov8m-pose.pt")
model.train(data=f"{dataset.location}/data.yaml", epochs=100, imgsz=640)
